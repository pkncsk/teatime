# %%
#%%

import pandas as pd

# %%
#%%

subfamily='THE1C'
the1c_patched = pd.read_csv(f'/home/pc575/rds/rds-kzfps-XrHDlpCeVDg/users/pakkanan/dev/teatime/debug/revised_workflow/{subfamily}.ltr_fix.txt', sep='\t', index_col =0)

# %%
#%%

df=the1c_patched

# %%
#%%

import pandas as pd

# Assuming your DataFrame is `df`

grouped = df.groupby('block_id')

# Prepare dict to hold block_id and row count for each category
summary = {
    'Single entry': [],
    'Two entries': [],
    'Two entries + match': [],
    'Two entries + mismatch': [],
    'More than two entries': [],
    'More than two entries + match': [],
    'More than two entries + mismatch': [],
    'Total match': [],
    'Total mismatch': [],
}

for block_id, group in grouped:
    row_count = len(group)
    ages = group['te_age'].unique()
    age_match = len(ages) == 1

    # Categorize by number of rows
    if row_count == 1:
        summary['Single entry'].append((block_id, row_count))
    elif row_count == 2:
        summary['Two entries'].append((block_id, row_count))
        if age_match:
            summary['Two entries + match'].append((block_id, row_count))
        else:
            summary['Two entries + mismatch'].append((block_id, row_count))
    else:
        summary['More than two entries'].append((block_id, row_count))
        if age_match:
            summary['More than two entries + match'].append((block_id, row_count))
        else:
            summary['More than two entries + mismatch'].append((block_id, row_count))

    # Track total matches/mismatches regardless of row count
    if age_match:
        summary['Total match'].append((block_id, row_count))
    else:
        summary['Total mismatch'].append((block_id, row_count))

# Grand totals for blocks and rows
total_blocks = len(grouped)
total_rows = len(df)

# Build summary table rows
summary_rows = []
for category, entries in summary.items():
    block_count = len(entries)
    row_count = sum(rc for _, rc in entries)
    summary_rows.append([
        category,
        block_count,
        f"{100 * block_count / total_blocks:.2f}%",
        row_count,
        f"{100 * row_count / total_rows:.2f}%"
    ])

# Append grand total row
summary_rows.append([
    "Grand total",
    total_blocks,
    "100.00%",
    total_rows,
    "100.00%"
])

# Create DataFrame for better formatting
summary_df = pd.DataFrame(summary_rows, columns=[
    'Category', 'Block count', 'Block %', 'Row count', 'Row %'
])

print(summary_df.to_string(index=False))
# Out:
#                         Category  Block count Block %  Row count   Row %
#                     Single entry         6643  81.62%       6643  67.86%
#                      Two entries         1361  16.72%       2722  27.81%
#              Two entries + match         1203  14.78%       2406  24.58%
#           Two entries + mismatch          158   1.94%        316   3.23%
#            More than two entries          135   1.66%        424   4.33%
#    More than two entries + match          107   1.31%        332   3.39%
# More than two entries + mismatch           28   0.34%         92   0.94%
#                      Total match         7953  97.71%       9381  95.83%
#                   Total mismatch          186   2.29%        408   4.17%
#                      Grand total         8139 100.00%       9789 100.00%

# %%
#%%

import pandas as pd

# Assuming your DataFrame is `df`

grouped = df.groupby('block_id')

# Prepare dict to hold block_id and row count for each category
summary = {
    'Single entry': [],
    'Two entries': [],
    'Two entries + match': [],
    'Two entries + mismatch': [],
    'More than two entries': [],
    'More than two entries + match': [],
    'More than two entries + mismatch': [],
    'Total match': [],
    'Total mismatch': [],
}

for block_id, group in grouped:
    row_count = len(group)
    ages = group['corrected_te_age'].unique()
    age_match = len(ages) == 1

    # Categorize by number of rows
    if row_count == 1:
        summary['Single entry'].append((block_id, row_count))
    elif row_count == 2:
        summary['Two entries'].append((block_id, row_count))
        if age_match:
            summary['Two entries + match'].append((block_id, row_count))
        else:
            summary['Two entries + mismatch'].append((block_id, row_count))
    else:
        summary['More than two entries'].append((block_id, row_count))
        if age_match:
            summary['More than two entries + match'].append((block_id, row_count))
        else:
            summary['More than two entries + mismatch'].append((block_id, row_count))

    # Track total matches/mismatches regardless of row count
    if age_match:
        summary['Total match'].append((block_id, row_count))
    else:
        summary['Total mismatch'].append((block_id, row_count))

# Grand totals for blocks and rows
total_blocks = len(grouped)
total_rows = len(df)

# Build summary table rows
summary_rows = []
for category, entries in summary.items():
    block_count = len(entries)
    row_count = sum(rc for _, rc in entries)
    summary_rows.append([
        category,
        block_count,
        f"{100 * block_count / total_blocks:.2f}%",
        row_count,
        f"{100 * row_count / total_rows:.2f}%"
    ])

# Append grand total row
summary_rows.append([
    "Grand total",
    total_blocks,
    "100.00%",
    total_rows,
    "100.00%"
])

# Create DataFrame for better formatting
summary_df = pd.DataFrame(summary_rows, columns=[
    'Category', 'Block count', 'Block %', 'Row count', 'Row %'
])

print(summary_df.to_string(index=False))
# Out:
#                         Category  Block count Block %  Row count   Row %
#                     Single entry         6643  81.62%       6643  67.86%
#                      Two entries         1361  16.72%       2722  27.81%
#              Two entries + match         1352  16.61%       2704  27.62%
#           Two entries + mismatch            9   0.11%         18   0.18%
#            More than two entries          135   1.66%        424   4.33%
#    More than two entries + match          132   1.62%        413   4.22%
# More than two entries + mismatch            3   0.04%         11   0.11%
#                      Total match         8127  99.85%       9760  99.70%
#                   Total mismatch           12   0.15%         29   0.30%
#                      Grand total         8139 100.00%       9789 100.00%

# %%
# %%

block_with_complete=the1c_patched[the1c_patched['tag'].str.contains('complete')]['block_id'].unique()

# %%
# %%

the1c_patched[the1c_patched['block_id'].isin(block_with_complete)]
# Out:
#                          tag                     internal_id  te_age int_type  \
# 0      1102358_bINT_complete   THE1C_1102358_bINT_complete_1    43.0     bINT
# 1      1102358_bINT_complete   THE1C_1102358_bINT_complete_2    28.8     bINT
# 2      3916656_bINT_complete   THE1C_3916656_bINT_complete_1    28.8     bINT
# 3      3916656_bINT_complete   THE1C_3916656_bINT_complete_2    43.0     bINT
# 4      4494792_bINT_complete   THE1C_4494792_bINT_complete_1    43.0     bINT
# ...                      ...                             ...     ...      ...
# 6321  2969595_aINT_singleton  THE1C_2969595_aINT_singleton_1    43.0     aINT
# 8999  4202027_aINT_singleton  THE1C_4202027_aINT_singleton_1    43.0     aINT
# 9277  4494792_aINT_singleton  THE1C_4494792_aINT_singleton_1    43.0     aINT
# 9421  4562625_aINT_singleton  THE1C_4562625_aINT_singleton_1    43.0     aINT
# 9717  4663391_aINT_singleton  THE1C_4663391_aINT_singleton_1    43.0     aINT
#
#            block_id  corrected_te_age
# 0     THE1C_1102358              43.0
# 1     THE1C_1102358              43.0
# 2     THE1C_3916656              28.8
# 3     THE1C_3916656              43.0
# 4     THE1C_4494792              43.0
# ...             ...               ...
# 6321  THE1C_2969595              43.0
# 8999  THE1C_4202027              43.0
# 9277  THE1C_4494792              43.0
# 9421  THE1C_4562625              43.0
# 9717  THE1C_4663391              43.0
#
# [65 rows x 6 columns]

# %%
# %%

# Step 1: Group by block_id
df=the1c_patched
grouped = df.groupby('block_id')

# Step 2: Filter groups with exactly 2 rows
two_row_groups = grouped.filter(lambda x: len(x) == 2)

# Step 3: Further filter those with both aINT and bINT
desired_blocks = two_row_groups.groupby('block_id').filter(
    lambda x: set(x['int_type']) == {'aINT', 'bINT'}
)

# Optional: get unique block_ids
result_block_ids = desired_blocks['block_id'].unique()

# Display results
print(result_block_ids)
# Out:
# ['THE1C_10428' 'THE1C_95785' 'THE1C_107665' 'THE1C_108898' 'THE1C_108916'
#  'THE1C_119183' 'THE1C_126114' 'THE1C_130770' 'THE1C_133234'
#  'THE1C_136703' 'THE1C_138407' 'THE1C_139224' 'THE1C_139227'
#  'THE1C_139323' 'THE1C_139838' 'THE1C_140300' 'THE1C_142125'
#  'THE1C_142670' 'THE1C_147324' 'THE1C_148009' 'THE1C_152311'
#  'THE1C_153472' 'THE1C_174710' 'THE1C_176546' 'THE1C_177214'
#  'THE1C_183121' 'THE1C_183210' 'THE1C_185112' 'THE1C_186368'
#  'THE1C_186430' 'THE1C_186647' 'THE1C_186880' 'THE1C_188995'
#  'THE1C_189949' 'THE1C_190816' 'THE1C_200936' 'THE1C_202007'
#  'THE1C_204830' 'THE1C_206347' 'THE1C_210479' 'THE1C_212417'
#  'THE1C_221860' 'THE1C_236038' 'THE1C_238016' 'THE1C_238241'
#  'THE1C_240130' 'THE1C_255832' 'THE1C_259677' 'THE1C_260172'
#  'THE1C_273943' 'THE1C_273956' 'THE1C_274923' 'THE1C_283060'
#  'THE1C_283659' 'THE1C_286806' 'THE1C_287069' 'THE1C_288417'
#  'THE1C_290426' 'THE1C_290505' 'THE1C_293139' 'THE1C_294747'
#  'THE1C_308859' 'THE1C_312449' 'THE1C_315387' 'THE1C_332522'
#  'THE1C_346592' 'THE1C_350504' 'THE1C_354035' 'THE1C_370083'
#  'THE1C_430475' 'THE1C_455818' 'THE1C_456987' 'THE1C_457053'
#  'THE1C_457608' 'THE1C_461820' 'THE1C_461942' 'THE1C_467135'
#  'THE1C_476523' 'THE1C_516565' 'THE1C_517274' 'THE1C_542171'
#  'THE1C_543493' 'THE1C_545284' 'THE1C_546463' 'THE1C_547159'
#  'THE1C_547177' 'THE1C_552380' 'THE1C_590599' 'THE1C_593622'
#  'THE1C_601368' 'THE1C_603854' 'THE1C_606228' 'THE1C_608703'
#  'THE1C_615656' 'THE1C_616082' 'THE1C_616731' 'THE1C_617795'
#  'THE1C_620433' 'THE1C_621660' 'THE1C_622588' 'THE1C_624091'
#  'THE1C_631976' 'THE1C_642930' 'THE1C_643731' 'THE1C_665168'
#  'THE1C_708502' 'THE1C_711396' 'THE1C_717255' 'THE1C_717653'
#  'THE1C_725309' 'THE1C_736119' 'THE1C_738317' 'THE1C_740780'
